# %% [markdown]
# ## Session 7 - Assignment 1

# %% [markdown]
# ### Task 1

# %% [markdown]
# #### Question 1
# Read the following data set:
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/
# Rename the columns as per the description from this file:
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.names

# %%
import numpy as np
import pandas as pd

adultnames = pd.read_fwf('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.names')

adultnames.rename(columns={adultnames.columns.values[0]:'h1'},inplace=True)

# Method 1
cols = list(adultnames.iloc[95:109].h1.str.split(":",expand=True)[0])
cols.append("salary")

adultdata = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',names=cols)

def trimAllColumns(df):
    trimcols = lambda x: x.strip() if type(x) is str else x
    return df.applymap(trimcols)

adultdata = trimAllColumns(adultdata)
adultdata.head(5)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %% [markdown]
# #### Create a sql db from adult dataset and name it sqladb

# %%
import sqlite3 as db
from pandas.io import sql

connection = db.connect('sqladb')
cursor = connection.cursor()

# adultdata.to_sql('adultdata', connection)
adultdata.to_sql('adultdata', connection, if_exists='append')

# %% [markdown]
# #### 1. Select 10 records from the adult sqladb

# %%
query = "SELECT * FROM adultData LIMIT 10;"
pd.read_sql(query, connection)
# Out:
#    index  age         workclass  fnlwgt  education  education-num  \
# 0      0   39         State-gov   77516  Bachelors             13
# 1      1   50  Self-emp-not-inc   83311  Bachelors             13
# 2      2   38           Private  215646    HS-grad              9
# 3      3   53           Private  234721       11th              7
# 4      4   28           Private  338409  Bachelors             13
# 5      5   37           Private  284582    Masters             14
# 6      6   49           Private  160187        9th              5
# 7      7   52  Self-emp-not-inc  209642    HS-grad              9
# 8      8   31           Private   45781    Masters             14
# 9      9   42           Private  159449  Bachelors             13
#
#           marital-status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3     Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4     Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 5     Married-civ-spouse    Exec-managerial           Wife  White  Female
# 6  Married-spouse-absent      Other-service  Not-in-family  Black  Female
# 7     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 8          Never-married     Prof-specialty  Not-in-family  White  Female
# 9     Married-civ-spouse    Exec-managerial        Husband  White    Male
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K
# 5             0             0              40  United-States  <=50K
# 6             0             0              16        Jamaica  <=50K
# 7             0             0              45  United-States   >50K
# 8         14084             0              50  United-States   >50K
# 9          5178             0              40  United-States   >50K

# %% [markdown]
# #### 2. Show me the average hours per week of all men who are working in private sector

# %%
query = """SELECT AVG([hours-per-week]) as Average FROM adultData where workclass='Private' and sex='Male';"""
pd.read_sql(query, connection)
# Out:
#      Average
# 0  42.221226

# %% [markdown]
# #### 3. Show me the frequency table for education, occupation and relationship, separately

# %%
print("Frequency Table for Education")
query = """SELECT education, COUNT(education) AS frequency FROM adultData GROUP BY education LIMIT 10;"""
print(pd.read_sql(query, connection))
# Out:
# Frequency Table for Education
#     education  frequency
# 0        10th        933
# 1        11th       1175
# 2        12th        433
# 3     1st-4th        168
# 4     5th-6th        333
# 5     7th-8th        646
# 6         9th        514
# 7  Assoc-acdm       1067
# 8   Assoc-voc       1382
# 9   Bachelors       5355

# %%
print("Frequency Table for occupation")
query = """SELECT occupation, COUNT(occupation) AS frequency FROM adultData GROUP BY education;"""
print(pd.read_sql(query, connection))
# Out:
# Frequency Table for occupation
#            occupation  frequency
# 0                   ?        933
# 1   Handlers-cleaners       1175
# 2        Craft-repair        433
# 3                   ?        168
# 4   Machine-op-inspct        333
# 5    Transport-moving        646
# 6       Other-service        514
# 7               Sales       1067
# 8        Craft-repair       1382
# 9        Adm-clerical       5355
# 10     Prof-specialty        413
# 11  Handlers-cleaners      10501
# 12    Exec-managerial       1723
# 13  Machine-op-inspct         51
# 14     Prof-specialty        576
# 15    Exec-managerial       7291

# %%
print("Frequency Table for relationship")
query = """SELECT relationship, COUNT(relationship) AS frequency FROM adultData GROUP BY education;"""
print(pd.read_sql(query, connection))
# Out:
# Frequency Table for relationship
#      relationship  frequency
# 0         Husband        933
# 1         Husband       1175
# 2   Not-in-family        433
# 3   Not-in-family        168
# 4         Husband        333
# 5         Husband        646
# 6   Not-in-family        514
# 7   Not-in-family       1067
# 8         Husband       1382
# 9   Not-in-family       5355
# 10        Husband        413
# 11  Not-in-family      10501
# 12           Wife       1723
# 13  Not-in-family         51
# 14           Wife        576
# 15        Husband       7291

# %% [markdown]
# #### 4. Are there any people who are married, working in private sector and having a masters degree

# %%
query = """SELECT * FROM adultData where workclass= 'Private' and education ='Masters' and [marital-status] like 'Married%';"""
pd.read_sql(query, connection)
# Out:
#      index  age workclass  fnlwgt education  education-num  \
# 0        5   37   Private  284582   Masters             14
# 1       87   33   Private  202051   Masters             14
# 2      100   76   Private  124191   Masters             14
# 13      Married-civ-spouse     Prof-specialty         Husband
# 14      Married-civ-spouse     Prof-specialty            Wife
# 15      Married-civ-spouse    Exec-managerial         Husband
# 16      Married-civ-spouse    Exec-managerial         Husband
# 17      Married-civ-spouse     Prof-specialty         Husband
# 18      Married-civ-spouse     Prof-specialty         Husband
# 19      Married-civ-spouse    Farming-fishing   Not-in-family
# 20      Married-civ-spouse     Prof-specialty         Husband
# 21      Married-civ-spouse   Transport-moving         Husband
# 22      Married-civ-spouse     Prof-specialty         Husband
# 23   Married-spouse-absent     Prof-specialty   Not-in-family
# 24      Married-civ-spouse              Sales         Husband
# 25      Married-civ-spouse     Prof-specialty         Husband
# 26      Married-civ-spouse     Prof-specialty         Husband
# 27      Married-civ-spouse     Prof-specialty         Husband
# 28      Married-civ-spouse     Prof-specialty         Husband
# 29      Married-civ-spouse    Exec-managerial         Husband
# ..                     ...                ...             ...
# 510     Married-civ-spouse     Prof-specialty         Husband
# 511     Married-civ-spouse  Machine-op-inspct         Husband
# 512     Married-civ-spouse     Prof-specialty         Husband
# 513     Married-civ-spouse     Prof-specialty         Husband
# 514     Married-civ-spouse     Prof-specialty         Husband
# 515     Married-civ-spouse     Prof-specialty         Husband
# 516     Married-civ-spouse     Prof-specialty         Husband
# 517     Married-civ-spouse     Prof-specialty            Wife
# 518     Married-civ-spouse    Exec-managerial         Husband
# 519     Married-civ-spouse     Prof-specialty         Husband
# 520     Married-civ-spouse       Tech-support         Husband
# 521     Married-civ-spouse     Prof-specialty         Husband
# 522     Married-civ-spouse    Exec-managerial         Husband
# 523     Married-civ-spouse    Exec-managerial         Husband
# 524     Married-civ-spouse     Prof-specialty         Husband
# 525     Married-civ-spouse    Exec-managerial         Husband
# 526     Married-civ-spouse     Prof-specialty         Husband
# 527     Married-civ-spouse     Prof-specialty         Husband
# 528     Married-civ-spouse     Prof-specialty         Husband
# 529     Married-civ-spouse     Prof-specialty         Husband
# 530     Married-civ-spouse    Exec-managerial         Husband
# 531     Married-civ-spouse     Prof-specialty         Husband
# 532     Married-civ-spouse     Prof-specialty         Husband
# 533     Married-civ-spouse     Prof-specialty         Husband
# 534     Married-civ-spouse     Prof-specialty         Husband
# 535     Married-civ-spouse       Tech-support         Husband
# 536     Married-civ-spouse     Prof-specialty         Husband
# 537     Married-civ-spouse    Exec-managerial         Husband
# 538     Married-civ-spouse     Prof-specialty            Wife
# 539     Married-civ-spouse    Exec-managerial         Husband
#
#                    race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                 White  Female             0             0              40
# 1                 White    Male             0             0              50
# 2                 White    Male             0             0              40
# 3                 White  Female             0             0              50
# 4                 White    Male          7298             0              40
# 5    Asian-Pac-Islander    Male          7298             0              35
# 6                 White    Male             0             0              40
# 7                 White    Male             0          1977              65
# 8                 White    Male             0             0              50
# 9                 White    Male             0          1977              45
# 10                White    Male             0             0              40
# 11                White    Male             0          1902              40
# 12                White    Male             0             0              40
# 13                White    Male             0             0              40
# 14   Asian-Pac-Islander  Female             0             0              50
# %%
query = """SELECT workclass,max(age),min(age),AVG(age) FROM adultData group by workclass;"""
pd.read_sql(query, connection)
# Out:
#           workclass  max(age)  min(age)   AVG(age)
# 0                 ?        90        17  40.960240
# 1       Federal-gov        90        17  42.590625
# 2         Local-gov        90        17  41.751075
# 3      Never-worked        30        17  20.571429
# 4           Private        90        17  36.797585
# 5      Self-emp-inc        84        17  46.017025
# 6  Self-emp-not-inc        90        17  44.969697
# 7         State-gov        81        17  39.436055
# 8       Without-pay        72        19  47.785714

# %% [markdown]
# #### 6. Calculate age distribution by country

# %%
query = """SELECT [native-country],age,count(*) FROM adultData where [native-country]<>' ?' group by [native-country],age;"""
pd.read_sql(query, connection)
# Out:
#      native-country  age  count(*)
# 0                 ?   17         2
# 1                 ?   18         8
# 2                 ?   19         5
# 3                 ?   20        10
# 4                 ?   21        11
# 5                 ?   22        12
# 6                 ?   23         6
# 7                 ?   24        14
# 8                 ?   25        11
# 9                 ?   26        18
# 10                ?   27        15
# 11                ?   28        19
# 12                ?   29        12
# 13                ?   30        19
# 14                ?   31        18
# 15                ?   32        17
# 16                ?   33        13
# 17                ?   34        24
# 18                ?   35        18
# 19                ?   36        23
# 20                ?   37        22
# 21                ?   38        20
# 22                ?   39        19
# 23                ?   40        12
# 24                ?   41        22
# 25                ?   42        24
# 26                ?   43        14
# 27                ?   44        10
# 28                ?   45        17
# 29                ?   46        15
# ...             ...  ...       ...
# 1251        Vietnam   37         2
# 1252        Vietnam   38         1
# 1253        Vietnam   40         1
# 1254        Vietnam   41         1
# 1255        Vietnam   43         2
# 1256        Vietnam   44         3
# 1257        Vietnam   45         3
# 1258        Vietnam   46         1
# 1259        Vietnam   48         1
# 1260        Vietnam   50         1
# 1261        Vietnam   51         1
# 1262        Vietnam   52         1
# 1263        Vietnam   53         1
# 1264        Vietnam   54         1
# 1265        Vietnam   63         1
# 1266        Vietnam   70         1
# 1267        Vietnam   73         2
# 1268     Yugoslavia   20         1
# 1269     Yugoslavia   22         1
# 1270     Yugoslavia   25         1
# 1271     Yugoslavia   29         1
# 1272     Yugoslavia   31         1
# 1273     Yugoslavia   35         2
# 1274     Yugoslavia   36         1
# 1275     Yugoslavia   40         1
# 1276     Yugoslavia   41         2
# 1277     Yugoslavia   43         1
# 1278     Yugoslavia   45         1
# 1279     Yugoslavia   56         2
# 1280     Yugoslavia   66         1
#
# [1281 rows x 3 columns]

# %% [markdown]
# #### 7. Compute a new column as 'Net-Capital-Gain' from the two columns 'capital-gain' and 'capital-loss'

# %%
# Calculation to find the Net Capital Gain = Capital Gain - Capital Loss

# Adding a new column to the table

query = """ALTER TABLE adultData ADD COLUMN netcapitalgain float;"""

# # query = """ALTER TABLE adultData ADD COLUMN '%s' 'float' NetCapitalGain;"""
# adultData.to_sql('adultData', netcapitalgain, if_exists='replace')
cursor.execute(query)

# %%
# Calculating Net Capital gain

query = """update adultdata set netcapitalgain=[capital-gain]-[capital-loss] ;"""
cursor.execute(query)

# %%
# Fetch and see if the new fielf is appearing with calculated value

query = "SELECT * FROM adultdata order by netcapitalgain desc LIMIT 10;"
print(pd.read_sql(query, connection))
# Out:
#    index  age         workclass  fnlwgt     education  education-num  \
# 0   1246   54      Self-emp-inc  166459   Prof-school             15
# 1   1368   52           Private  152234       HS-grad              9
# 2   1482   53      Self-emp-inc  263925       HS-grad              9
# 3   1528   52           Private  118025     Bachelors             13
# 4   1616   46           Private  370119   Prof-school             15
# 5   1682   43           Private  176270     Bachelors             13
# 6   1765   49           Private  159816     Bachelors             13
# 7   1771   50           Private  171338  Some-college             10
# 8   1826   22  Self-emp-not-inc  202920       HS-grad              9
# 9   2103   43      Self-emp-inc  172826  Some-college             10
#
#        marital-status       occupation relationship                race  \
# 0  Married-civ-spouse   Prof-specialty      Husband               White
# 1  Married-civ-spouse  Exec-managerial      Husband  Asian-Pac-Islander
# 2  Married-civ-spouse            Sales      Husband               White
# 3  Married-civ-spouse  Exec-managerial      Husband               White
# 4  Married-civ-spouse   Prof-specialty      Husband               White
# 5  Married-civ-spouse  Exec-managerial      Husband               White
# 6  Married-civ-spouse   Prof-specialty         Wife               White
# 7  Married-civ-spouse  Exec-managerial      Husband               White
# 8       Never-married   Prof-specialty    Unmarried               White
# 9  Married-civ-spouse            Sales      Husband               White
#
#       sex  capital-gain  capital-loss  hours-per-week      native-country  \
# 0    Male         99999             0              60       United-States
# 1    Male         99999             0              40               Japan
# 2    Male         99999             0              40       United-States
# 3    Male         99999             0              50       United-States
# 4    Male         99999             0              60       United-States
# 5    Male         99999             0              60       United-States
# 6  Female         99999             0              20       United-States
# 7    Male         99999             0              50       United-States
# 8  Female         99999             0              40  Dominican-Republic
# 9    Male         99999             0              55       United-States
#
#   salary  netcapitalgain
# 0   >50K         99999.0
# 1   >50K         99999.0
# 2   >50K         99999.0
# 3   >50K         99999.0
# 4   >50K         99999.0
# 5   >50K         99999.0
# 6   >50K         99999.0
# 7   >50K         99999.0
# 8   >50K         99999.0
# 9   >50K         99999.0

# %% [markdown]
# ### Task 2
# ### Read the following data set:
# ### https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data

# %%
# 1. Create an sqlalchemy engine using a sample from the data set

from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base

engine = create_engine('sqlite:///:memory:', echo=True)
connection = engine.raw_connection()
Base = declarative_base()

adultdata.to_sql('adultdata', connection)

select_query = """SELECT * FROM adultdata LIMIT 5;""" 

#Executes select query
engine.execute(select_query).fetchall()
# Out:
# 2019-02-08 11:03:08,182 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-02-08 11:03:08,182 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-08 11:03:08,182 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-02-08 11:03:08,182 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-08 11:03:08,454 INFO sqlalchemy.engine.base.Engine SELECT * FROM adultdata LIMIT 5;
# 2019-02-08 11:03:08,454 INFO sqlalchemy.engine.base.Engine ()
# [(0, 39, 'State-gov', 77516, 'Bachelors', 13, 'Never-married', 'Adm-clerical', 'Not-in-family', 'White', 'Male', 2174, 0, 40, 'United-States', '<=50K'),
#  (1, 50, 'Self-emp-not-inc', 83311, 'Bachelors', 13, 'Married-civ-spouse', 'Exec-managerial', 'Husband', 'White', 'Male', 0, 0, 13, 'United-States', '<=50K'),
#  (2, 38, 'Private', 215646, 'HS-grad', 9, 'Divorced', 'Handlers-cleaners', 'Not-in-family', 'White', 'Male', 0, 0, 40, 'United-States', '<=50K'),
#  (3, 53, 'Private', 234721, '11th', 7, 'Married-civ-spouse', 'Handlers-cleaners', 'Husband', 'Black', 'Male', 0, 0, 40, 'United-States', '<=50K'),
#  (4, 28, 'Private', 338409, 'Bachelors', 13, 'Married-civ-spouse', 'Prof-specialty', 'Wife', 'Black', 'Female', 0, 0, 40, 'Cuba', '<=50K')]

# %% [markdown]
# #### 2. Write two basic update queries

# %%
#First update query
update_query_1 = '''UPDATE adultdata SET [native-country]='USA' where [native-country]=' United-States' ;'''
engine.execute(update_query_1)


#Second update query
update_query_2 = '''UPDATE adultdata SET sex='M' where sex=' Male';'''
engine.execute(update_query_2)

#Select query 
select_query = '''SELECT * FROM adultdata LIMIT 5;''' 
engine.execute(select_query).fetchall()
# Out:
# 2019-02-08 11:03:13,565 INFO sqlalchemy.engine.base.Engine UPDATE adultdata SET [native-country]='USA' where [native-country]=' United-States' ;
# 2019-02-08 11:03:13,566 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-08 11:03:13,576 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-02-08 11:03:13,578 INFO sqlalchemy.engine.base.Engine UPDATE adultdata SET sex='M' where sex=' Male';
# 2019-02-08 11:03:13,579 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-08 11:03:13,589 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-02-08 11:03:13,592 INFO sqlalchemy.engine.base.Engine SELECT * FROM adultdata LIMIT 5;
# 2019-02-08 11:03:13,594 INFO sqlalchemy.engine.base.Engine ()
# [(0, 39, 'State-gov', 77516, 'Bachelors', 13, 'Never-married', 'Adm-clerical', 'Not-in-family', 'White', 'Male', 2174, 0, 40, 'United-States', '<=50K'),
#  (1, 50, 'Self-emp-not-inc', 83311, 'Bachelors', 13, 'Married-civ-spouse', 'Exec-managerial', 'Husband', 'White', 'Male', 0, 0, 13, 'United-States', '<=50K'),
#  (2, 38, 'Private', 215646, 'HS-grad', 9, 'Divorced', 'Handlers-cleaners', 'Not-in-family', 'White', 'Male', 0, 0, 40, 'United-States', '<=50K'),
#  (3, 53, 'Private', 234721, '11th', 7, 'Married-civ-spouse', 'Handlers-cleaners', 'Husband', 'Black', 'Male', 0, 0, 40, 'United-States', '<=50K'),
#  (4, 28, 'Private', 338409, 'Bachelors', 13, 'Married-civ-spouse', 'Prof-specialty', 'Wife', 'Black', 'Female', 0, 0, 40, 'Cuba', '<=50K')]

# %% [markdown]
# #### 3. Write two delete queries

# %%
#First delete query
update_query_1 = """delete from adultdata where [native-country]='?' ;"""
engine.execute(update_query_1)
#Second delete query
update_query_2 = """delete from adultdata where occupation='?';"""
engine.execute(update_query_2)
#Select query 
select_query = """SELECT * FROM adultdata where [native-country]='?' LIMIT 5;""" 
engine.execute(select_query)
# Out:
# 2019-02-08 11:10:35,374 INFO sqlalchemy.engine.base.Engine delete from adultdata where [native-country]='?' ;
# 2019-02-08 11:10:35,375 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-08 11:10:35,387 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-02-08 11:10:35,390 INFO sqlalchemy.engine.base.Engine delete from adultdata where occupation='?';
# 2019-02-08 11:10:35,394 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-08 11:10:35,407 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-02-08 11:10:35,410 INFO sqlalchemy.engine.base.Engine SELECT * FROM adultdata where [native-country]='?' LIMIT 5;
# 2019-02-08 11:10:35,411 INFO sqlalchemy.engine.base.Engine ()

# %% [markdown]
# #### 4. Write two filter queries

# %%
#First filter query
filter_query1 = '''select * from adultdata where [native-country]=' Cuba';'''
engine.execute(filter_query1).fetchall()

#Second filter query
filter_query2 = '''select sex,[capital-gain] from adultdata where [capital-gain] > '9999' LIMIT 5;'''
engine.execute(filter_query2).fetchall()
# Out:
# 2019-02-08 11:10:36,782 INFO sqlalchemy.engine.base.Engine select * from adultdata where [native-country]=' Cuba';
# 2019-02-08 11:10:36,784 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-08 11:10:36,793 INFO sqlalchemy.engine.base.Engine select sex,[capital-gain] from adultdata where [capital-gain] > '9999' LIMIT 5;
# 2019-02-08 11:10:36,796 INFO sqlalchemy.engine.base.Engine ()
# [('Female', 14084),
#  ('Female', 14344),
#  ('Male', 15024),
#  ('Female', 14084),
#  ('Female', 15024)]

# %% [markdown]
# #### 5 Write two function queries

# %% [markdown]
# Function Query 1

# %%
function_query1 = '''select workclass,sum([capital-gain]),sum([capital-loss]) from adultdata where workclass<>'?' group by workclass LIMIT 5;'''
engine.execute(function_query1).fetchall()
# Out:
# 2019-02-08 11:10:42,481 INFO sqlalchemy.engine.base.Engine select workclass,sum([capital-gain]),sum([capital-loss]) from adultdata where workclass<>'?' group by workclass LIMIT 5;
# 2019-02-08 11:10:42,482 INFO sqlalchemy.engine.base.Engine ()
# [('Federal-gov', 784879, 105363),
#  ('Local-gov', 1714019, 228038),
#  ('Private', 19608520, 1774623),
#  ('Self-emp-inc', 5166742, 164864),
#  ('Self-emp-not-inc', 4780923, 288815)]

# %% [markdown]
# Function Query 2

# %%
function_query2 = '''select max([hours-per-week]) ,min([hours-per-week]),avg([hours-per-week]) from adultdata;'''
engine.execute(function_query2).fetchall()
# Out:
# 2019-02-08 11:10:49,459 INFO sqlalchemy.engine.base.Engine select max([hours-per-week]) ,min([hours-per-week]),avg([hours-per-week]) from adultdata;
# 2019-02-08 11:10:49,461 INFO sqlalchemy.engine.base.Engine ()
# [(99, 1, 40.93123798156621)]
